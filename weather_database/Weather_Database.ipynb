# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 768

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nabire
# Processing Record 2 of Set 1 | dicabisagan
# Processing Record 3 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | olafsvik
# Processing Record 6 of Set 1 | coihaique
# Processing Record 7 of Set 1 | dingle
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | saint george
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | pucara
# Processing Record 14 of Set 1 | vanavara
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | mezen
# Processing Record 18 of Set 1 | atasu
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | katsuura
# Processing Record 21 of Set 1 | silvino lobos
# Processing Record 22 of Set 1 | inhambane
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | banda aceh
# Processing Record 26 of Set 1 | melnikovo
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | kruisfontein
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | narsaq
# Processing Record 33 of Set 1 | guerrero negro
# Processing Record 34 of Set 1 | faanui
# Processing Record 35 of Set 1 | nemuro
# Processing Record 36 of Set 1 | padang
# Processing Record 37 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 1 | port augusta
# Processing Record 39 of Set 1 | vestmannaeyjar
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | krasnoselkup
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | hervey bay
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 1 | majene
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | nurota
# Processing Record 1 of Set 2 | tual
# Processing Record 2 of Set 2 | akyab
# Processing Record 3 of Set 2 | santa rosa
# Processing Record 4 of Set 2 | xiongzhou
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | mookane
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | alpena
# Processing Record 12 of Set 2 | evensk
# Processing Record 13 of Set 2 | soderhamn
# Processing Record 14 of Set 2 | pevek
# Processing Record 15 of Set 2 | zeya
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | maldonado
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | sola
# Processing Record 23 of Set 2 | verkhnevilyuysk
# Processing Record 24 of Set 2 | mount darwin
# Processing Record 25 of Set 2 | mataura
# Processing Record 26 of Set 2 | cherskiy
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | madeji
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | hofn
# Processing Record 31 of Set 2 | san patricio
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | atar
# Processing Record 35 of Set 2 | monrovia
# Processing Record 36 of Set 2 | sao filipe
# Processing Record 37 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 2 | seoul
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | plouzane
# Processing Record 41 of Set 2 | bilma
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | ciras
# City not found. Skipping...
# Processing Record 44 of Set 2 | auka
# Processing Record 45 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | pedreiras
# Processing Record 48 of Set 2 | charcas
# Processing Record 49 of Set 2 | el balyana
# City not found. Skipping...
# Processing Record 50 of Set 2 | krasnogorskoye
# Processing Record 1 of Set 3 | qaqortoq
# Processing Record 2 of Set 3 | berezovyy
# Processing Record 3 of Set 3 | sungairaya
# Processing Record 4 of Set 3 | zhuhai
# Processing Record 5 of Set 3 | eureka
# Processing Record 6 of Set 3 | upernavik
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | constitucion
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 3 | fort saint james
# Processing Record 14 of Set 3 | egvekinot
# Processing Record 15 of Set 3 | half moon bay
# Processing Record 16 of Set 3 | anadyr
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | praia
# Processing Record 20 of Set 3 | caravelas
# Processing Record 21 of Set 3 | benguela
# Processing Record 22 of Set 3 | yumen
# Processing Record 23 of Set 3 | bluff
# Processing Record 24 of Set 3 | iquique
# Processing Record 25 of Set 3 | aklavik
# Processing Record 26 of Set 3 | vardo
# Processing Record 27 of Set 3 | adre
# Processing Record 28 of Set 3 | el alto
# Processing Record 29 of Set 3 | ilulissat
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 3 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 33 of Set 3 | tashtyp
# Processing Record 34 of Set 3 | naron
# Processing Record 35 of Set 3 | piacabucu
# Processing Record 36 of Set 3 | port moresby
# Processing Record 37 of Set 3 | athabasca
# Processing Record 38 of Set 3 | gamba
# Processing Record 39 of Set 3 | manicore
# Processing Record 40 of Set 3 | gat
# Processing Record 41 of Set 3 | berdigestyakh
# Processing Record 42 of Set 3 | valls
# Processing Record 43 of Set 3 | puerto del rosario
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | kachug
# Processing Record 46 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 3 | vila velha
# Processing Record 48 of Set 3 | bredasdorp
# Processing Record 49 of Set 3 | chuy
# Processing Record 50 of Set 3 | roma
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | panguna
# Processing Record 4 of Set 4 | koulamoutou
# Processing Record 5 of Set 4 | bangassou
# Processing Record 6 of Set 4 | tete
# Processing Record 7 of Set 4 | ratnagiri
# Processing Record 8 of Set 4 | rioja
# Processing Record 9 of Set 4 | luwuk
# Processing Record 10 of Set 4 | marrakesh
# Processing Record 11 of Set 4 | nanortalik
# Processing Record 12 of Set 4 | broken hill
# Processing Record 13 of Set 4 | comodoro rivadavia
# Processing Record 14 of Set 4 | tromso
# Processing Record 15 of Set 4 | waverly
# Processing Record 16 of Set 4 | ferme-neuve
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | paamiut
# Processing Record 19 of Set 4 | lebu
# Processing Record 20 of Set 4 | gimli
# Processing Record 21 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 22 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 4 | beira
# Processing Record 24 of Set 4 | yellowknife
# Processing Record 25 of Set 4 | rocha
# Processing Record 26 of Set 4 | tondano
# Processing Record 27 of Set 4 | quatre cocos
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | kadyy
# Processing Record 30 of Set 4 | bilibino
# Processing Record 31 of Set 4 | cap malheureux
# Processing Record 32 of Set 4 | port lincoln
# Processing Record 33 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 4 | yar-sale
# Processing Record 35 of Set 4 | pingliang
# Processing Record 36 of Set 4 | poya
# Processing Record 37 of Set 4 | acara
# Processing Record 38 of Set 4 | praia da vitoria
# Processing Record 39 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 40 of Set 4 | cabo san lucas
# Processing Record 41 of Set 4 | mecca
# Processing Record 42 of Set 4 | yerbogachen
# Processing Record 43 of Set 4 | klyuchi
# Processing Record 44 of Set 4 | qeshm
# Processing Record 45 of Set 4 | erenhot
# Processing Record 46 of Set 4 | salalah
# Processing Record 47 of Set 4 | manacapuru
# Processing Record 48 of Set 4 | tomaszow lubelski
# Processing Record 49 of Set 4 | hasaki
# Processing Record 50 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 5 | jacmel
# Processing Record 2 of Set 5 | asyut
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | redmond
# Processing Record 5 of Set 5 | manokwari
# Processing Record 6 of Set 5 | tianmen
# Processing Record 7 of Set 5 | itarema
# Processing Record 8 of Set 5 | takoradi
# Processing Record 9 of Set 5 | chapais
# Processing Record 10 of Set 5 | kapaa
# Processing Record 11 of Set 5 | regina
# Processing Record 12 of Set 5 | alofi
# Processing Record 13 of Set 5 | santa maria
# Processing Record 14 of Set 5 | qaanaaq
# Processing Record 15 of Set 5 | bambanglipuro
# Processing Record 16 of Set 5 | thai binh
# Processing Record 17 of Set 5 | salaverry
# Processing Record 18 of Set 5 | prince rupert
# Processing Record 19 of Set 5 | chongwe
# Processing Record 20 of Set 5 | san jeronimo
# Processing Record 21 of Set 5 | sitka
# Processing Record 22 of Set 5 | san jose
# Processing Record 23 of Set 5 | san quintin
# Processing Record 24 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 5 | howard springs
# Processing Record 26 of Set 5 | yantai
# Processing Record 27 of Set 5 | freeport
# Processing Record 28 of Set 5 | ames
# Processing Record 29 of Set 5 | axim
# Processing Record 30 of Set 5 | oranjestad
# Processing Record 31 of Set 5 | filingue
# Processing Record 32 of Set 5 | taoudenni
# Processing Record 33 of Set 5 | port hardy
# Processing Record 34 of Set 5 | strasice
# Processing Record 35 of Set 5 | necochea
# Processing Record 36 of Set 5 | ribeira grande
# Processing Record 37 of Set 5 | roanoke rapids
# Processing Record 38 of Set 5 | ocos
# Processing Record 39 of Set 5 | gejiu
# Processing Record 40 of Set 5 | port macquarie
# Processing Record 41 of Set 5 | katha
# City not found. Skipping...
# Processing Record 42 of Set 5 | papara
# Processing Record 43 of Set 5 | touros
# Processing Record 44 of Set 5 | fort nelson
# Processing Record 45 of Set 5 | goundi
# Processing Record 46 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 5 | diego de almagro
# Processing Record 48 of Set 5 | beaverlodge
# Processing Record 49 of Set 5 | udachnyy
# Processing Record 50 of Set 5 | ovalle
# Processing Record 1 of Set 6 | leshukonskoye
# Processing Record 2 of Set 6 | tukrah
# Processing Record 3 of Set 6 | chokurdakh
# Processing Record 4 of Set 6 | goma
# Processing Record 5 of Set 6 | lagoa
# Processing Record 6 of Set 6 | waddan
# Processing Record 7 of Set 6 | fuengirola
# Processing Record 8 of Set 6 | muros
# Processing Record 9 of Set 6 | port hueneme
# Processing Record 10 of Set 6 | lavrentiya
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | port hawkesbury
# Processing Record 13 of Set 6 | opuwo
# Processing Record 14 of Set 6 | butaritari
# Processing Record 15 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 6 | boizenburg
# Processing Record 18 of Set 6 | tasiilaq
# Processing Record 19 of Set 6 | margate
# Processing Record 20 of Set 6 | niksic
# Processing Record 21 of Set 6 | provideniya
# Processing Record 22 of Set 6 | tiksi
# Processing Record 23 of Set 6 | taltal
# Processing Record 24 of Set 6 | puerto carreno
# Processing Record 25 of Set 6 | cumaral
# Processing Record 26 of Set 6 | abu samrah
# Processing Record 27 of Set 6 | shelburne
# Processing Record 28 of Set 6 | dembi dolo
# Processing Record 29 of Set 6 | severo-kurilsk
# Processing Record 30 of Set 6 | avanigadda
# Processing Record 31 of Set 6 | ardesen
# Processing Record 32 of Set 6 | palmer
# Processing Record 33 of Set 6 | clyde river
# Processing Record 34 of Set 6 | pecos
# Processing Record 35 of Set 6 | geraldton
# Processing Record 36 of Set 6 | sobolevo
# Processing Record 37 of Set 6 | russkiy aktash
# Processing Record 38 of Set 6 | kijang
# Processing Record 39 of Set 6 | erzin
# Processing Record 40 of Set 6 | channel-port aux basques
# Processing Record 41 of Set 6 | camacha
# Processing Record 42 of Set 6 | murgab
# Processing Record 43 of Set 6 | puerto madryn
# Processing Record 44 of Set 6 | narrabri
# Processing Record 45 of Set 6 | ngunguru
# Processing Record 46 of Set 6 | flagstaff
# Processing Record 47 of Set 6 | malatya
# Processing Record 48 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 49 of Set 6 | talnakh
# Processing Record 50 of Set 6 | poitiers
# Processing Record 1 of Set 7 | bathsheba
# Processing Record 2 of Set 7 | kalakamati
# Processing Record 3 of Set 7 | bontang
# Processing Record 4 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 7 | burica
# City not found. Skipping...
# Processing Record 6 of Set 7 | murupara
# Processing Record 7 of Set 7 | wanaka
# Processing Record 8 of Set 7 | fernley
# Processing Record 9 of Set 7 | sidney
# Processing Record 10 of Set 7 | kloulklubed
# Processing Record 11 of Set 7 | beloha
# Processing Record 12 of Set 7 | pangnirtung
# Processing Record 13 of Set 7 | cayenne
# Processing Record 14 of Set 7 | jardim
# Processing Record 15 of Set 7 | matara
# Processing Record 16 of Set 7 | iqaluit
# Processing Record 17 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 18 of Set 7 | husavik
# Processing Record 19 of Set 7 | te anau
# Processing Record 20 of Set 7 | heinola
# Processing Record 21 of Set 7 | carupano
# Processing Record 22 of Set 7 | vikhorevka
# Processing Record 23 of Set 7 | reynosa
# Processing Record 24 of Set 7 | kalmunai
# Processing Record 25 of Set 7 | penzance
# Processing Record 26 of Set 7 | mehamn
# Processing Record 27 of Set 7 | poum
# Processing Record 28 of Set 7 | grand gaube
# Processing Record 29 of Set 7 | kudahuvadhoo
# Processing Record 30 of Set 7 | lafiagi
# Processing Record 31 of Set 7 | pacific grove
# Processing Record 32 of Set 7 | lethem
# Processing Record 33 of Set 7 | lamlash
# Processing Record 34 of Set 7 | lorengau
# Processing Record 35 of Set 7 | dalvik
# Processing Record 36 of Set 7 | mogwase
# Processing Record 37 of Set 7 | dubti
# Processing Record 38 of Set 7 | vilcun
# Processing Record 39 of Set 7 | terpsithea
# Processing Record 40 of Set 7 | thunder bay
# Processing Record 41 of Set 7 | aykhal
# Processing Record 42 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 7 | mount isa
# Processing Record 45 of Set 7 | ngaoundere
# Processing Record 46 of Set 7 | ostrovnoy
# Processing Record 47 of Set 7 | hami
# Processing Record 48 of Set 7 | gewane
# Processing Record 49 of Set 7 | biak
# Processing Record 50 of Set 7 | mayo
# Processing Record 1 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 8 | luganville
# Processing Record 3 of Set 8 | fortuna
# Processing Record 4 of Set 8 | huarmey
# Processing Record 5 of Set 8 | pisco
# Processing Record 6 of Set 8 | pingzhuang
# Processing Record 7 of Set 8 | olinda
# Processing Record 8 of Set 8 | neryungri
# Processing Record 9 of Set 8 | bonaventure
# Processing Record 10 of Set 8 | abnub
# Processing Record 11 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 8 | jibuti
# Processing Record 13 of Set 8 | cidreira
# Processing Record 14 of Set 8 | bolshaya glushitsa
# Processing Record 15 of Set 8 | zhanaozen
# Processing Record 16 of Set 8 | rawson
# Processing Record 17 of Set 8 | hamilton
# Processing Record 18 of Set 8 | charters towers
# Processing Record 19 of Set 8 | adelaide
# Processing Record 20 of Set 8 | srandakan
# Processing Record 21 of Set 8 | kamaishi
# Processing Record 22 of Set 8 | waspan
# Processing Record 23 of Set 8 | hun
# Processing Record 24 of Set 8 | bullhead city
# Processing Record 25 of Set 8 | kavieng
# Processing Record 26 of Set 8 | bandarbeyla
# Processing Record 27 of Set 8 | shingu
# Processing Record 28 of Set 8 | isangel
# Processing Record 29 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 30 of Set 8 | ozernovskiy
# Processing Record 31 of Set 8 | riviere-au-renard
# Processing Record 32 of Set 8 | la ronge
# Processing Record 33 of Set 8 | coquimbo
# Processing Record 34 of Set 8 | velyka lepetykha
# Processing Record 35 of Set 8 | hay river
# Processing Record 36 of Set 8 | vao
# Processing Record 37 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 8 | kamenka
# Processing Record 39 of Set 8 | bodden town
# Processing Record 40 of Set 8 | ponta do sol
# Processing Record 41 of Set 8 | nakamura
# Processing Record 42 of Set 8 | pasni
# Processing Record 43 of Set 8 | homer
# Processing Record 44 of Set 8 | turukhansk
# Processing Record 45 of Set 8 | leningradskiy
# Processing Record 46 of Set 8 | brae
# Processing Record 47 of Set 8 | kibala
# Processing Record 48 of Set 8 | puri
# Processing Record 49 of Set 8 | balabac
# Processing Record 50 of Set 8 | klaksvik
# Processing Record 1 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 2 of Set 9 | waipawa
# Processing Record 3 of Set 9 | esperance
# Processing Record 4 of Set 9 | codrington
# Processing Record 5 of Set 9 | minas
# Processing Record 6 of Set 9 | limon
# Processing Record 7 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 9 | dongsheng
# Processing Record 9 of Set 9 | xiongshi
# City not found. Skipping...
# Processing Record 10 of Set 9 | kutum
# Processing Record 11 of Set 9 | borger
# Processing Record 12 of Set 9 | bac lieu
# Processing Record 13 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 9 | victoria
# Processing Record 15 of Set 9 | boyle
# Processing Record 16 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 9 | dunedin
# Processing Record 18 of Set 9 | seaford
# Processing Record 19 of Set 9 | mayumba
# Processing Record 20 of Set 9 | hirara
# Processing Record 21 of Set 9 | donskoye
# Processing Record 22 of Set 9 | madang
# Processing Record 23 of Set 9 | dronfield
# Processing Record 24 of Set 9 | izhma
# Processing Record 25 of Set 9 | the pas
# Processing Record 26 of Set 9 | nalut
# Processing Record 27 of Set 9 | bubaque
# Processing Record 28 of Set 9 | korla
# Processing Record 29 of Set 9 | lages
# Processing Record 30 of Set 9 | rio gallegos
# Processing Record 31 of Set 9 | januaria
# Processing Record 32 of Set 9 | dudinka
# Processing Record 33 of Set 9 | montepuez
# Processing Record 34 of Set 9 | honiara
# Processing Record 35 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 9 | marathopolis
# City not found. Skipping...
# Processing Record 37 of Set 9 | virginia beach
# Processing Record 38 of Set 9 | samarai
# Processing Record 39 of Set 9 | kapoeta
# Processing Record 40 of Set 9 | souris
# Processing Record 41 of Set 9 | san rafael
# Processing Record 42 of Set 9 | karratha
# Processing Record 43 of Set 9 | champerico
# Processing Record 44 of Set 9 | morgan city
# Processing Record 45 of Set 9 | vitim
# Processing Record 46 of Set 9 | cienfuegos
# Processing Record 47 of Set 9 | griffith
# Processing Record 48 of Set 9 | komsomolskiy
# Processing Record 49 of Set 9 | moranbah
# Processing Record 50 of Set 9 | khandyga
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 3 of Set 10 | sabha
# Processing Record 4 of Set 10 | kuah
# Processing Record 5 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 10 | nha trang
# Processing Record 7 of Set 10 | san ramon
# Processing Record 8 of Set 10 | larsnes
# Processing Record 9 of Set 10 | zimapan
# Processing Record 10 of Set 10 | omboue
# Processing Record 11 of Set 10 | bage
# Processing Record 12 of Set 10 | borisoglebskiy
# Processing Record 13 of Set 10 | novosil
# Processing Record 14 of Set 10 | launceston
# Processing Record 15 of Set 10 | san cristobal
# Processing Record 16 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 10 | villarrobledo
# Processing Record 18 of Set 10 | bluffton
# Processing Record 19 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 10 | play cu
# City not found. Skipping...
# Processing Record 21 of Set 10 | raudeberg
# Processing Record 22 of Set 10 | karaman
# Processing Record 23 of Set 10 | navashino
# Processing Record 24 of Set 10 | banff
# Processing Record 25 of Set 10 | recco
# Processing Record 26 of Set 10 | bukama
# Processing Record 27 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 28 of Set 10 | kenitra
# Processing Record 29 of Set 10 | vilyuysk
# Processing Record 30 of Set 10 | labuhan
# Processing Record 31 of Set 10 | gabaldon
# Processing Record 32 of Set 10 | trairi
# Processing Record 33 of Set 10 | buala
# Processing Record 34 of Set 10 | pemangkat
# Processing Record 35 of Set 10 | lata
# Processing Record 36 of Set 10 | phalaborwa
# Processing Record 37 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 10 | flinders
# Processing Record 39 of Set 10 | acapulco
# Processing Record 40 of Set 10 | ulladulla
# Processing Record 41 of Set 10 | kahului
# Processing Record 42 of Set 10 | tombouctou
# Processing Record 43 of Set 10 | moba
# Processing Record 44 of Set 10 | borogontsy
# Processing Record 45 of Set 10 | parana
# Processing Record 46 of Set 10 | teya
# Processing Record 47 of Set 10 | nagua
# Processing Record 48 of Set 10 | nome
# Processing Record 49 of Set 10 | pitimbu
# Processing Record 50 of Set 10 | zhanjiang
# Processing Record 1 of Set 11 | tazovskiy
# Processing Record 2 of Set 11 | sinnamary
# Processing Record 3 of Set 11 | iskateley
# Processing Record 4 of Set 11 | hobyo
# Processing Record 5 of Set 11 | sao joao da barra
# Processing Record 6 of Set 11 | rolla
# Processing Record 7 of Set 11 | goulburn
# Processing Record 8 of Set 11 | chor
# Processing Record 9 of Set 11 | san luis
# Processing Record 10 of Set 11 | northam
# Processing Record 11 of Set 11 | bejar
# Processing Record 12 of Set 11 | amapa
# Processing Record 13 of Set 11 | ahipara
# Processing Record 14 of Set 11 | tilichiki
# Processing Record 15 of Set 11 | onokhoy
# Processing Record 16 of Set 11 | ambilobe
# Processing Record 17 of Set 11 | zhigansk
# Processing Record 18 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 11 | kristiinankaupunki
# Processing Record 20 of Set 11 | ossora
# Processing Record 21 of Set 11 | meulaboh
# Processing Record 22 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 11 | lompoc
# Processing Record 24 of Set 11 | hambantota
# Processing Record 25 of Set 11 | tingrela
# City not found. Skipping...
# Processing Record 26 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 27 of Set 11 | riyadh
# Processing Record 28 of Set 11 | namibe
# Processing Record 29 of Set 11 | chicama
# Processing Record 30 of Set 11 | malchin
# Processing Record 31 of Set 11 | fomboni
# Processing Record 32 of Set 11 | shar
# Processing Record 33 of Set 11 | boa vista
# Processing Record 34 of Set 11 | savinka
# Processing Record 35 of Set 11 | esil
# Processing Record 36 of Set 11 | san juan
# Processing Record 37 of Set 11 | broome
# Processing Record 38 of Set 11 | chlorakas
# Processing Record 39 of Set 11 | bulaevo
# Processing Record 40 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 11 | foam lake
# Processing Record 42 of Set 11 | new richmond
# Processing Record 43 of Set 11 | kotido
# Processing Record 44 of Set 11 | rutana
# Processing Record 45 of Set 11 | daryapur
# Processing Record 46 of Set 11 | osmanabad
# Processing Record 47 of Set 11 | darfield
# Processing Record 48 of Set 11 | tigil
# Processing Record 49 of Set 11 | jalu
# Processing Record 50 of Set 11 | panjab
# Processing Record 1 of Set 12 | namatanai
# Processing Record 2 of Set 12 | rio grande
# Processing Record 3 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 4 of Set 12 | ahmadpur east
# Processing Record 5 of Set 12 | stonewall
# Processing Record 6 of Set 12 | port blair
# Processing Record 7 of Set 12 | port-gentil
# Processing Record 8 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 12 | marawi
# Processing Record 10 of Set 12 | lunca bradului
# Processing Record 11 of Set 12 | ojinaga
# Processing Record 12 of Set 12 | viking
# Processing Record 13 of Set 12 | maragogi
# Processing Record 14 of Set 12 | saint-pierre
# Processing Record 15 of Set 12 | acaponeta
# Processing Record 16 of Set 12 | vostok
# Processing Record 17 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 18 of Set 12 | ancud
# Processing Record 19 of Set 12 | emerald
# Processing Record 20 of Set 12 | juneau
# Processing Record 21 of Set 12 | mount gambier
# Processing Record 22 of Set 12 | batagay-alyta
# Processing Record 23 of Set 12 | aksu
# Processing Record 24 of Set 12 | shakhtinsk
# Processing Record 25 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 12 | cayambe
# Processing Record 27 of Set 12 | lieksa
# Processing Record 28 of Set 12 | valisoara
# Processing Record 29 of Set 12 | missungwi
# Processing Record 30 of Set 12 | witrivier
# City not found. Skipping...
# Processing Record 31 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 12 | mangai
# Processing Record 33 of Set 12 | luebo
# Processing Record 34 of Set 12 | chase
# Processing Record 35 of Set 12 | byron bay
# Processing Record 36 of Set 12 | dharchula
# Processing Record 37 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 12 | guru har sahai
# Processing Record 39 of Set 12 | khristoforovo
# City not found. Skipping...
# Processing Record 40 of Set 12 | fethiye
# Processing Record 41 of Set 12 | kirakira
# Processing Record 42 of Set 12 | polyarnyy
# Processing Record 43 of Set 12 | espinosa
# Processing Record 44 of Set 12 | sao gabriel da cachoeira
# Processing Record 45 of Set 12 | deputatskiy
# Processing Record 46 of Set 12 | richards bay
# Processing Record 47 of Set 12 | balkanabat
# Processing Record 48 of Set 12 | gushikawa
# Processing Record 49 of Set 12 | houma
# Processing Record 50 of Set 12 | chara
# Processing Record 1 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 13 | sorland
# Processing Record 3 of Set 13 | sicamous
# Processing Record 4 of Set 13 | tarauaca
# Processing Record 5 of Set 13 | tymovskoye
# Processing Record 6 of Set 13 | lysva
# Processing Record 7 of Set 13 | lakes entrance
# Processing Record 8 of Set 13 | gorlice
# Processing Record 9 of Set 13 | joshimath
# Processing Record 10 of Set 13 | along
# Processing Record 11 of Set 13 | tautira
# Processing Record 12 of Set 13 | kawalu
# Processing Record 13 of Set 13 | kupang
# Processing Record 14 of Set 13 | fenelon falls
# Processing Record 15 of Set 13 | whitianga
# Processing Record 16 of Set 13 | sakakah
# Processing Record 17 of Set 13 | kununurra
# Processing Record 18 of Set 13 | la crosse
# Processing Record 19 of Set 13 | kieta
# Processing Record 20 of Set 13 | eyl
# Processing Record 21 of Set 13 | takaungu
# Processing Record 22 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 23 of Set 13 | japura
# Processing Record 24 of Set 13 | biaora
# Processing Record 25 of Set 13 | srednekolymsk
# Processing Record 26 of Set 13 | altyn-topkan
# Processing Record 27 of Set 13 | porto santo
# Processing Record 28 of Set 13 | springbok
# Processing Record 29 of Set 13 | myanaung
# Processing Record 30 of Set 13 | yulara
# Processing Record 31 of Set 13 | morrope
# Processing Record 32 of Set 13 | chikoy
# City not found. Skipping...
# Processing Record 33 of Set 13 | luba
# Processing Record 34 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 13 | sovetskiy
# Processing Record 36 of Set 13 | yuma
# Processing Record 37 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 38 of Set 13 | sabang
# Processing Record 39 of Set 13 | pontianak
# Processing Record 40 of Set 13 | chagoda
# Processing Record 41 of Set 13 | santa cruz
# Processing Record 42 of Set 13 | olga
# Processing Record 43 of Set 13 | shimoda
# Processing Record 44 of Set 13 | bakel
# Processing Record 45 of Set 13 | marsa matruh
# Processing Record 46 of Set 13 | san carlos de bariloche
# Processing Record 47 of Set 13 | nisia floresta
# Processing Record 48 of Set 13 | mapiripan
# Processing Record 49 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 50 of Set 13 | barcelona
# Processing Record 1 of Set 14 | terra nova
# Processing Record 2 of Set 14 | tezu
# Processing Record 3 of Set 14 | hovd
# Processing Record 4 of Set 14 | aktau
# Processing Record 5 of Set 14 | plettenberg bay
# Processing Record 6 of Set 14 | sisimiut
# Processing Record 7 of Set 14 | hurghada
# Processing Record 8 of Set 14 | ukhta
# Processing Record 9 of Set 14 | pastavy
# Processing Record 10 of Set 14 | guiratinga
# Processing Record 11 of Set 14 | ginda
# Processing Record 12 of Set 14 | nizhniy ufaley
# Processing Record 13 of Set 14 | llandrindod wells
# Processing Record 14 of Set 14 | lixourion
# Processing Record 15 of Set 14 | malm
# Processing Record 16 of Set 14 | havre-saint-pierre
# Processing Record 17 of Set 14 | guinope
# Processing Record 18 of Set 14 | makakilo city
# Processing Record 19 of Set 14 | ekhabi
# Processing Record 20 of Set 14 | sibolga
# Processing Record 21 of Set 14 | coromandel
# Processing Record 22 of Set 14 | oro valley
# Processing Record 23 of Set 14 | mareeba
# Processing Record 24 of Set 14 | roald
# Processing Record 25 of Set 14 | lazaro cardenas
# Processing Record 26 of Set 14 | galle
# Processing Record 27 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 28 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 14 | beloretsk
# Processing Record 30 of Set 14 | marsh harbour
# Processing Record 31 of Set 14 | sampit
# Processing Record 32 of Set 14 | tiarei
# Processing Record 33 of Set 14 | barabinsk
# Processing Record 34 of Set 14 | poso
# Processing Record 35 of Set 14 | kapit
# Processing Record 36 of Set 14 | jiaocheng
# Processing Record 37 of Set 14 | big spring
# Processing Record 38 of Set 14 | kargil
# Processing Record 39 of Set 14 | starodub
# Processing Record 40 of Set 14 | sur
# Processing Record 41 of Set 14 | harqalah
# Processing Record 42 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 43 of Set 14 | maningrida
# Processing Record 44 of Set 14 | haldensleben
# Processing Record 45 of Set 14 | la asuncion
# Processing Record 46 of Set 14 | vanimo
# Processing Record 47 of Set 14 | tura
# Processing Record 48 of Set 14 | iranduba
# Processing Record 49 of Set 14 | konevo
# Processing Record 50 of Set 14 | tsabong
# Processing Record 1 of Set 15 | goderich
# Processing Record 2 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 15 | bowen
# Processing Record 4 of Set 15 | cardston
# Processing Record 5 of Set 15 | lukang
# Processing Record 6 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 7 of Set 15 | jyvaskyla
# Processing Record 8 of Set 15 | belmonte
# Processing Record 9 of Set 15 | qui nhon
# Processing Record 10 of Set 15 | pathein
# Processing Record 11 of Set 15 | portland
# Processing Record 12 of Set 15 | tizimin
# Processing Record 13 of Set 15 | acajutla
# Processing Record 14 of Set 15 | coulihaut
# City not found. Skipping...
# Processing Record 15 of Set 15 | miri
# Processing Record 16 of Set 15 | ariquemes
# Processing Record 17 of Set 15 | los llanos de aridane
# Processing Record 18 of Set 15 | yeppoon
# Processing Record 19 of Set 15 | inuvik
# Processing Record 20 of Set 15 | kamakwie
# Processing Record 21 of Set 15 | harlingen
# Processing Record 22 of Set 15 | keti bandar
# Processing Record 23 of Set 15 | la uribe
# City not found. Skipping...
# Processing Record 24 of Set 15 | koslan
# Processing Record 25 of Set 15 | paso de carrasco
# Processing Record 26 of Set 15 | tonstad
# Processing Record 27 of Set 15 | sioux lookout
# Processing Record 28 of Set 15 | dubbo
# Processing Record 29 of Set 15 | wattegama
# Processing Record 30 of Set 15 | college
# Processing Record 31 of Set 15 | natal
# Processing Record 32 of Set 15 | nyurba
# Processing Record 33 of Set 15 | mglin
# Processing Record 34 of Set 15 | grindavik
# Processing Record 35 of Set 15 | canoinhas
# Processing Record 36 of Set 15 | andapa
# Processing Record 37 of Set 15 | lisakovsk
# Processing Record 38 of Set 15 | mitsamiouli
# Processing Record 39 of Set 15 | mogzon
# Processing Record 40 of Set 15 | sorrento
# Processing Record 41 of Set 15 | mojoagung
# Processing Record 42 of Set 15 | lusambo
# Processing Record 43 of Set 15 | churapcha
# Processing Record 44 of Set 15 | alta floresta
# Processing Record 45 of Set 15 | rassvet
# Processing Record 46 of Set 15 | talcahuano
# Processing Record 47 of Set 15 | san vicente
# Processing Record 48 of Set 15 | kuala krai
# City not found. Skipping...
# Processing Record 49 of Set 15 | leticia
# Processing Record 50 of Set 15 | asau
# Processing Record 1 of Set 16 | zhaoqing
# Processing Record 2 of Set 16 | ewa beach
# Processing Record 3 of Set 16 | kure
# Processing Record 4 of Set 16 | gazojak
# Processing Record 5 of Set 16 | rumoi
# Processing Record 6 of Set 16 | fairbanks
# Processing Record 7 of Set 16 | san policarpo
# Processing Record 8 of Set 16 | san pedro
# Processing Record 9 of Set 16 | garowe
# Processing Record 10 of Set 16 | teluk nibung
# Processing Record 11 of Set 16 | keflavik
# Processing Record 12 of Set 16 | mariental
# Processing Record 13 of Set 16 | cururupu
# Processing Record 14 of Set 16 | ryotsu
# Processing Record 15 of Set 16 | nizwa
# Processing Record 16 of Set 16 | ketchikan
# Processing Record 17 of Set 16 | aquiraz
# Processing Record 18 of Set 16 | north bend
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 692

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Nabire      ID  -3.3667  135.4833     75.54        92         100
# 1   Dicabisagan      PH  17.0818  122.4157     75.52        88         100
# 2       Rikitea      PF -23.1203 -134.9692     78.26        72          76
# 3      Olafsvik      IS  64.8945  -23.7142     29.80        93         100
# 4     Coihaique      CL -45.5752  -72.0662     78.49        35         100
# 5        Dingle      PH  10.9995  122.6711     74.28        93          91
# 6        Hobart      AU -42.8794  147.3294     60.66        83          75
# 7        Avarua      CK -21.2078 -159.7750     80.65        78         100
# 8     Mahebourg      MU -20.4081   57.7000     81.25        84          86
# 9  Saint George      US  37.1041 -113.5841     70.36        18           0
#
#    Wind Speed Current Description
# 0        3.56     overcast clouds
# 1        6.51     overcast clouds
# 2       12.10          light rain
# 3       10.89                snow
# 4       10.13     overcast clouds
# 5        6.38     overcast clouds
# 6       12.66       broken clouds
# 7        4.61     overcast clouds
# 8       13.56          light rain
# 9        5.01           clear sky

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
